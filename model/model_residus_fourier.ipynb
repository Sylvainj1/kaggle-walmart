# %%
#il s'agit ici de calculer le residus et ensuite prédire ces résidus sur les données nouvelles pour pouvoir ajouter
#cette variables explicatives à nos models notamment lighGBM

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import lightgbm as lgb

# %%
fourier_each_item = pd.read_csv('/Users/jerem/cours_esiee_paris/E4/kaggle_walmart/fourier_each_item.csv')

# %%
fourier_each_item
# Out:
#                                     id    d_1548    d_1549    d_1550  \
# 0          FOODS_1_001_CA_1_validation  0.674633  0.737291  0.523595
# 1          FOODS_1_001_CA_2_validation  1.588128  0.733491  0.123893
# 2          FOODS_1_001_CA_3_validation  1.958086  0.767862  0.686620
# 3          FOODS_1_001_CA_4_validation  0.395325  0.220562  0.139595
# 4          FOODS_1_001_TX_1_validation  0.057722  0.041872  0.186977
# ...                                ...       ...       ...       ...
# 30485  HOUSEHOLD_2_516_TX_2_validation  0.246105  0.461133  0.497872
# 30486  HOUSEHOLD_2_516_TX_3_validation  0.098045  0.119822  0.010789
# 30487  HOUSEHOLD_2_516_WI_1_validation  0.004875  0.152489  0.087394
# 30488  HOUSEHOLD_2_516_WI_2_validation  0.080768  0.086026  0.016704
# 30489  HOUSEHOLD_2_516_WI_3_validation  0.015379  0.212792  0.312338
#
#          d_1551    d_1552    d_1553    d_1554    d_1555    d_1556  ...  \
# ...
