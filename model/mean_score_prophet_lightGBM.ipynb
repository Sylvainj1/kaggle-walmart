# %%
import pandas as pd
import numpy as np

# %%
prophet = pd.read_csv("../../submission/prophet_tuned_without_eval_computed.csv")

# %%
light = pd.read_csv("../../submission/submission_1_all_data.csv")

# %%
light_hugo = pd.read_csv("/Users/jerem/cours_esiee_paris/E4/kaggle_walmart/submission/submission_hugo_lightGBM.csv")

# %%
submission_mean_p_l_lh = light.copy()

# %%
prophet.drop('Unnamed: 0', axis = 1, inplace= True)

# %%
light_hugo
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.897045  0.829586  0.825668
# 1          FOODS_1_001_CA_2_validation  0.872577  0.851137  0.821639
# 2          FOODS_1_001_CA_3_validation  1.143622  1.092276  0.971518
# 3          FOODS_1_001_CA_4_validation  0.397865  0.339242  0.344583
# 4          FOODS_1_001_TX_1_validation  0.182859  0.181492  0.183131
# ...                                ...       ...       ...       ...
# 30485  HOUSEHOLD_2_516_TX_2_validation  0.255059  0.236031  0.258619
# 30486  HOUSEHOLD_2_516_TX_3_validation  0.161384  0.149353  0.156618
# 30487  HOUSEHOLD_2_516_WI_1_validation  0.088258  0.084978  0.084986
# 30488  HOUSEHOLD_2_516_WI_2_validation  0.041591  0.040907  0.040369
# 30489  HOUSEHOLD_2_516_WI_3_validation  0.052889  0.051296  0.050161
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
light_hugo = pd.concat([light_hugo,light[30490:]], ignore_index= True)
light_hugo
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.897045  0.829586  0.825668
# 1          FOODS_1_001_CA_2_validation  0.872577  0.851137  0.821639
# 2          FOODS_1_001_CA_3_validation  1.143622  1.092276  0.971518
# 3          FOODS_1_001_CA_4_validation  0.397865  0.339242  0.344583
# 4          FOODS_1_001_TX_1_validation  0.182859  0.181492  0.183131
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.238312  0.233083  0.265550
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.165081  0.157491  0.166611
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.081770  0.079970  0.082175
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.040956  0.043507  0.042750
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.054468  0.057348  0.056690
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
prophet
# Out:
#                                   id        F1        F2        F3        F4  \
# 0      HOBBIES_1_001_CA_1_validation  0.715834  0.915793  0.737153  0.679746
# 1      HOBBIES_1_002_CA_1_validation  0.264101  0.313151  0.088360  0.134565
# 2      HOBBIES_1_003_CA_1_validation  0.491322  0.397691  0.396348  0.427642
# 3      HOBBIES_1_004_CA_1_validation  0.935152  0.403906  0.743346  1.628049
# 4      HOBBIES_1_005_CA_1_validation  1.520631  1.583654  1.547123  1.662655
# ...                              ...       ...       ...       ...       ...
# 60975    FOODS_3_823_WI_3_evaluation  0.225189  0.093887  0.126004  0.087226
# 60976    FOODS_3_824_WI_3_evaluation  0.089006  0.001973  0.003428  0.014074
# 60977    FOODS_3_825_WI_3_evaluation  0.397447  0.243549  0.209129  0.192611
# 60978    FOODS_3_826_WI_3_evaluation  1.729231  1.789361  1.681637  1.698416
# 60979    FOODS_3_827_WI_3_evaluation  1.933008  2.013490  1.770946  1.653288
#
# ...

# %%
light
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.913235  0.827773  0.819731
# 1          FOODS_1_001_CA_2_validation  0.953068  1.072191  0.958676
# 2          FOODS_1_001_CA_3_validation  1.128027  1.075911  0.912882
# 3          FOODS_1_001_CA_4_validation  0.398870  0.353666  0.351945
# 4          FOODS_1_001_TX_1_validation  0.198043  0.192291  0.184541
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.238312  0.233083  0.265550
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.165081  0.157491  0.166611
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.081770  0.079970  0.082175
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.040956  0.043507  0.042750
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.054468  0.057348  0.056690
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
submission_mean_p_l_lh
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.913235  0.827773  0.819731
# 1          FOODS_1_001_CA_2_validation  0.953068  1.072191  0.958676
# 2          FOODS_1_001_CA_3_validation  1.128027  1.075911  0.912882
# 3          FOODS_1_001_CA_4_validation  0.398870  0.353666  0.351945
# 4          FOODS_1_001_TX_1_validation  0.198043  0.192291  0.184541
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.238312  0.233083  0.265550
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.165081  0.157491  0.166611
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.081770  0.079970  0.082175
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.040956  0.043507  0.042750
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.054468  0.057348  0.056690
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
submission_mean_p_l_lh = submission_mean_p_l_lh.set_index('id')
prophet = prophet.set_index('id')
light = light.set_index('id')
light_hugo = light_hugo.set_index('id')

# %%
prophet = prophet.reindex(index=light.index)

# %%
prophet
# Out:
#                                        F1        F2        F3        F4  \
# id
# FOODS_1_001_CA_1_validation      0.801172  0.496831  0.824167  1.041874
# FOODS_1_001_CA_2_validation      1.303677  1.209265  0.752748  0.697430
# FOODS_1_001_CA_3_validation      0.000000  0.000000  0.000000  0.000000
# FOODS_1_001_CA_4_validation      0.747951  0.376488  0.620451  0.570586
# FOODS_1_001_TX_1_validation      0.211350  0.431709  0.227418  0.242261
# ...                                   ...       ...       ...       ...
# HOUSEHOLD_2_516_TX_2_evaluation  0.168423  0.107955  0.177941  0.186888
# HOUSEHOLD_2_516_TX_3_evaluation  0.181669  0.197185  0.200834  0.225228
# HOUSEHOLD_2_516_WI_1_evaluation  0.021041  0.014522  0.022815  0.020581
# HOUSEHOLD_2_516_WI_2_evaluation  0.040762  0.050111  0.052153  0.043228
# HOUSEHOLD_2_516_WI_3_evaluation  0.082672  0.059697  0.064955  0.112833
#
#                                        F5        F6        F7        F8  \
# id
# ...

# %%
submission_mean_p_l = (prophet + light + light_hugo)

# %%
submission_mean_p_l
# Out:
#                                        F1        F2        F3        F4  \
# id
# FOODS_1_001_CA_1_validation      2.611451  2.154191  2.469566  2.640062
# FOODS_1_001_CA_2_validation      3.129322  3.132592  2.533063  2.817546
# FOODS_1_001_CA_3_validation      2.271649  2.168187  1.884399  1.859219
# FOODS_1_001_CA_4_validation      1.544687  1.069396  1.316979  1.272641
# FOODS_1_001_TX_1_validation      0.592252  0.805492  0.595090  0.609949
# ...                                   ...       ...       ...       ...
# HOUSEHOLD_2_516_TX_2_evaluation  0.645046  0.574121  0.709041  0.686138
# HOUSEHOLD_2_516_TX_3_evaluation  0.511832  0.512168  0.534056  0.543632
# HOUSEHOLD_2_516_WI_1_evaluation  0.184582  0.174462  0.187165  0.193259
# HOUSEHOLD_2_516_WI_2_evaluation  0.122674  0.137126  0.137653  0.207988
# HOUSEHOLD_2_516_WI_3_evaluation  0.191609  0.174393  0.178335  0.231404
#
#                                        F5        F6        F7        F8  \
# id
# ...

# %%
submission_mean_p_l = submission_mean_p_l/3

# %%
submission_mean_p_l
# Out:
#                                        F1        F2        F3        F4  \
# id
# FOODS_1_001_CA_1_validation      0.870484  0.718064  0.823189  0.880021
# FOODS_1_001_CA_2_validation      1.043107  1.044197  0.844354  0.939182
# FOODS_1_001_CA_3_validation      0.757216  0.722729  0.628133  0.619740
# FOODS_1_001_CA_4_validation      0.514896  0.356465  0.438993  0.424214
# FOODS_1_001_TX_1_validation      0.197417  0.268497  0.198363  0.203316
# ...                                   ...       ...       ...       ...
# HOUSEHOLD_2_516_TX_2_evaluation  0.215015  0.191374  0.236347  0.228713
# HOUSEHOLD_2_516_TX_3_evaluation  0.170611  0.170723  0.178019  0.181211
# HOUSEHOLD_2_516_WI_1_evaluation  0.061527  0.058154  0.062388  0.064420
# HOUSEHOLD_2_516_WI_2_evaluation  0.040891  0.045709  0.045884  0.069329
# HOUSEHOLD_2_516_WI_3_evaluation  0.063870  0.058131  0.059445  0.077135
#
#                                        F5        F6        F7        F8  \
# id
# ...

# %%
submission_mean_p_l.reset_index()
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.870484  0.718064  0.823189
# 1          FOODS_1_001_CA_2_validation  1.043107  1.044197  0.844354
# 2          FOODS_1_001_CA_3_validation  0.757216  0.722729  0.628133
# 3          FOODS_1_001_CA_4_validation  0.514896  0.356465  0.438993
# 4          FOODS_1_001_TX_1_validation  0.197417  0.268497  0.198363
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.215015  0.191374  0.236347
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.170611  0.170723  0.178019
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.061527  0.058154  0.062388
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.040891  0.045709  0.045884
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.063870  0.058131  0.059445
#
#              F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
submission_mean_p_l.to_csv('mean_prophet_light_lighthugo.csv')
